# %% [markdown]
# # 머신러닝의 이해
# ## #01. 인공지능, 머신러닝, 딥러닝
# ![1.png](attachment:1.png)
# ### 1) 인공지능(AI)
# - 컴퓨터가 인간과 같은 지능적인 행동을 할 수 있게 해주는 기법들을 연구하는 분야.
# ### 2) 머신러닝
# - 인공지능 연구분야의 방법론 중 하나
# - 데이터를 이용해 컴퓨터가 어떤 지식이나 패턴을 학습하는 것.
# - 지도학습, 비지도학습, 강화학습 등의 방법론
# ### 3) 딥러닝
# - 머신러닝의 여러 방법론 중 하나
# - 인공신경망을 깊게 여러 층 쌓아 올려 학습하는 방식
#
# ## #02. 전통적인 프로그래밍과 머신러닝의 차이
# ### 1) 프로그래밍
# ![2.png](attachment:2.png)
# 논리적인 흐름을 만드는 것이 중요함
# ### 2) 심볼릭 AI
# 명시적인 규칙을 충분하게 만들어 지식을 다루면 인간수준의 인공지능을 만들 수 있다고 생각하는 방법
#
# ### 3) 머신러닝
# ![3.png](attachment:3.png)
# 데이터와 결과값을 통하여 규칙을 찾아내는 것이 목적
#
# ## #03. 머신러닝의 분류
# ### 1) 알고리즘의 분류
# ![4.png](attachment:4.png)
# #### 지도학습
# 의도하는 결과가 있을 때 사용
#
# 학습하는 동안 모델은 입력으로 들어온 값으로 변수를 조정하여 출력에 매핑
#
# ![5.png](attachment:5.png)
#
# 이미 알려진 사례를 바탕으로 일반화된 모델을 만들어 의사결정 프로세스를 자동화 하는 것
#
# 알고리즘에 입력과 기대되는 출력을 제공하고 알고리즘은 주어진 입력에서 원하는 출력을 만드는 방법을 찾는다
#
# - 편지 봉투에 손으로 쓴 우편번호 숫자 판별
# |구분|데이터|
# |--|--|
# |input|손글씨를 스캔한 이미지|
# |output|우편번호 숫자|
#
# 머신러닝 모델 구축에 쓸 데이터셋을 만들려면 많은 편지봉투를 모아 원하는 출력값을 기록해 놓아야 학습가능
#
#
# - 의료 영상 이미지에 기반한 종양판단
# |구분|데이터|
# |--|--|
# |input|이미지(엑스레이,CT)|
# |output|종양의 양성 여부|
#
# 머신러닝 모델 구축에 쓸 데이터셋을 만들려면 많은 이미지를 모아 원하는 출력값을 기록해 놓아야 학습가능
#
#
#
#
# #### 비지도 학습
#
# 의도하는 결과가 없을 때 사용
#
# 입력 데이터 집합을 비슷한 유형의 집합으로 분류한다.
# ![6.png](attachment:6.png)
#
#
# 사전에
# #### 강화학습
# - 결정을 내리도록 할 때 사용한다.
# - 결정을 했을 때의 성공/실패에 따라 주어진 입력값에 대한 결정이 점차 달라진다.
# - 학습을 할 수록 입력에 대한 결과 예측이 가능하게 한다.
# ![7.png](attachment:7.png)
#
# ### 2) 분석 목적에 따른 알고리즘 구분
#
# ![Alt text](https://github.com/leekh4232/MegaitDataAnalysis/blob/main/F.%2520%25EB%258D%25B0%25EC%259D%25B4%25ED%2584%25B0%2520%25EB%25A7%2588%25EC%259D%25B4%25EB%258B%259D/01.%2520%25EB%25A8%25B8%25EC%258B%25A0%25EB%259F%25AC%25EB%258B%259D%2520%25EA%25B0%259C%25EC%259A%2594/res/8.svg)
#
# ### 3) 결론
#
# |구분	|목적|
# |통계분석	|소수(샘플,표본)에서 다수(모집단)을 추정한다.|
# |빅데이터 분석|	컴퓨팅 파워의 발전으로 표본집단의 선정이 의미 없어짐|
# |머신러닝|	과거로부터 미래를 예측한다.|
