# %% [markdown]
# # 단순 선형회귀
#
# 독립변수의 변화에 따른 종속변수를 추론하는 통계
#
# 하나의 독립변수화 하나의 종속변수가 주엊니다.
#
# 가장 간단한 회귀분산
#
# 파이선에서는 statemodels 패키지와 sklearn 패키지가 회귀분석 기능을 제공한다
#
# sklearnm은 머신러닝에 속하기 때문에 여기서는 statemodel만 사용
# ## #01. 작업준비
#
# ### 패키지 참조

# %%
import pandas as pd
from statsmodels.formula.api import ols
from matplotlib import pyplot as plt
import seaborn as sns
import sys
import os 
sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))
from helper import pearson_r

# %% [markdown]
# ### 데이터 가져오기

# %%
df= pd.read_excel('https://data.hossam.kr/E04/cars.xlsx')
df
# Out:
#     speed  dist
# 0       4     2
# 1       4    10
# 2       7     4
# 3       7    22
# 4       8    16
# 5       9    10
# 6      10    18
# 7      10    26
# 8      10    34
# 9      11    17
# 10     11    28
# 11     12    14
# 12     12    20
# 13     12    24
# 14     12    28
# 15     13    26
# 16     13    34
# 17     13    34
# 18     13    46
# 19     14    26
# 20     14    36
# 21     14    60
# 22     14    80
# 23     15    20
# 24     15    26
# 25     15    54
# 26     16    32
# 27     16    40
# 28     17    32
# 29     17    40
# 30     17    50
# 31     18    42
# 32     18    56
# 33     18    76
# 34     18    84
# 35     19    36
# 36     19    46
# 37     19    68
# 38     20    32
# 39     20    48
# 40     20    52
# 41     20    56
# 42     20    64
# 43     22    66
# 44     23    54
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %% [markdown]
# ## #02.탐색적 데이터 분석
# ### 산점도 그래프

# %%
plt.rcParams["font.family"] = 'AppleGothic' if sys.platform == 'darwin' else 'Malgun Gothic'
plt.rcParams["font.size"] = 12
plt.rcParams["figure.figsize"] = (10, 4)
plt.rcParams["axes.unicode_minus"] = False

# %%
sns.regplot(data= df,x='speed',y='dist')
plt.show()
plt.close()

# %% [markdown]
# ## #03. 추론통계
# ### 1) 상관분석

# %%
rdf = pearson_r(df)

# %%
rdf
# Out:
#              statistic        pvalue  result
# fields
# speedvsdist   0.806895  1.489836e-12    True
# distvsspeed   0.806895  1.489836e-12    True

# %% [markdown]
# 상관분석 결과 p값이 0.05보다 작으므로 속도와 제동거리간 상관관계가 유의하다고 할 수 있다.

# %% [markdown]
# ### 2) 회귀분석
# $y=ax+b$ 에 따라 종속 ~ 독립 형태로 표현식 구성
#
# #### 분석을 위한 학습모델 구성

# %%
model = ols("dist ~ speed",data=df)
model

# %% [markdown]
# #### 분석 수행

# %%
fit = model.fit()
fit

# %% [markdown]
# #### 분석결과 확인

# %%
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   dist   R-squared:                       0.651
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     89.57
# Date:                Mon, 24 Jul 2023   Prob (F-statistic):           1.49e-12
# Time:                        16:00:45   Log-Likelihood:                -206.58
# No. Observations:                  50   AIC:                             417.2
# Df Residuals:                      48   BIC:                             421.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -17.5791      6.758     -2.601      0.012     -31.168      -3.990
# ...

# %% [markdown]
# #### 분석결과 해석
#
# ##### R-squared(R제곱, 결정계수)
#
# 모형의 설명력을 의미 : dist 제동거리를 speed가 약 65% 설명한다
#
# ##### Adj R-squared
# 독립변수가 여러 개인 다중회귀분석에서 사용
#
# 독립변수의 개수와 표본의 크기를 고려하여 R-squared 값 보정
#
# 서로다른 모형을 비교할 떄는 이 지표가 높은 쪽을 선택한다
#
# ##### F-statistic: 89.57, Prob(F-statistic): 1.49e-12
# 회귀모형에 대한 (통계적) 유의미성 검증 결과, 유의미함 (p < 0.05)
#
# 즉, 이 모형은 주어진 표본 뿐 아니라 모집단에서도 의미있는 모형이라 할 수 있음
#
# ##### AIC, BIC
# 로그 우도: 종속변수가 정규분포라고 가정했을 때의 우도
#
# 로그우도를 독립변수의 수로 보정한 값 (작을 수록 좋다)
#
# ###### 회귀계수 해석
#
# 데이터로부터 얻은 계수의 추정치
#
# 절편의 추정치는 -17.5791
#
# speed 의 계수 추정치는 3.9324로 speed가 1 증가할 떄마다 dist가 3.9324 증가한다는 것으ㅡㄹ 의미
#
# -> dist = -17.5791+ 3.9324*speed
#
# ##### p값
# 모집단에서 계수가 0일 때, 현재와 같은 크기의 표본에서 이러한 계수가 추정될 확률
#
# 이 확률이 매우 작다는 것은, 모집단에서 speed의 계수가 정확히 3.9324는 아니더라도 현재의 표본과 비슷하게 0보다 큰 어떤 범위에 있을 가능성이 높다는 것을 의미
#
# 보통 5%와 같은 유의수준을 정하여 p값이 그보다 작으면(p < 0.05), "통계적으로 유의미하다"라고 정리

# %% [markdown]
# ## #04. 결과 보고
# ### 모형적합도 보고
# F분포의 파라미터 2개와 그 때의 F값, p-value의 유의수준 비교를 명시
#
# dist에 대하여 speed로 예측하는 회귀분석을 실시한 결과, 이 회귀모형은 통계적으로 유의미하였다(F(1,48) = 89.57, p < 0.05)
# ### 독립변수에 대해 보고
# speed의 회귀계수는 3.9324로, dist에 대하여 유의미한 예측변인인 것으로 나타났다.(t(48) = 9.464, p < 0.05)
