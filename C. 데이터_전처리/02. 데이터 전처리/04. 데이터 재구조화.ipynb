# %% [markdown]
# # 데이터 전처리 (3)  - 데이터 재구조화
#
# ###  mel 추가

# %% [markdown]
# ## #01. 패키지 준비

# %%
from pandas import read_excel , DataFrame,melt
from pandas import merge, concat, pivot_table, crosstab

# %% [markdown]
# ### 2. 데이터 가져오기

# %%
고객 = read_excel('https://data.hossam.kr/C02/city_people.xlsx')

고객
# Out:
#    도시    연도       인구   지역
# 0  서울  2015  9904312  수도권
# 1  서울  2010  9631482  수도권
# 2  서울  2005  9762546  수도권
# 3  부산  2015  3448737  경상권
# 4  부산  2010  3393191  경상권
# 5  부산  2005  3512547  경상권
# 6  인천  2015  2890451  수도권
# 7  인천  2010  2632035  수도권

# %%
매출= read_excel('https://data.hossam.kr/money.xlsx')
매출
# Out:
#    고객번호      금액
# 0  1001   10000
# 1  1001   20000
# 2  1005   15000
# 3  1006    5000
# 4  1008  100000
# 5  1001   30000

# %% [markdown]
# ## #02. 피벗 테이블
#
# #### 1. 샘플데이터 가져오기

# %%
df = read_excel("https://data.hossam.kr/C02/city_people.xlsx")
df
# Out:
#    도시    연도       인구   지역
# 0  서울  2015  9904312  수도권
# 1  서울  2010  9631482  수도권
# 2  서울  2005  9762546  수도권
# 3  부산  2015  3448737  경상권
# 4  부산  2010  3393191  경상권
# 5  부산  2005  3512547  경상권
# 6  인천  2015  2890451  수도권
# 7  인천  2010  2632035  수도권

# %% [markdown]
# #### 2. 피벗테이블 기본

# %%
pivot_table(df,
            index = "도시",
            columns='연도',
            values="인구")
# Out:
# 연도       2005       2010       2015
# 도시
# 부산  3512547.0  3393191.0  3448737.0
# 서울  9762546.0  9631482.0  9904312.0
# 인천        NaN  2632035.0  2890451.0

# %% [markdown]
# #### 3. 중복 데이터의 집계방법 지정하기

# %%
pivot_table(df,
            index = "지역",
            columns = '연도',
            values = '인구',
            aggfunc= 'mean')
# Out:
# 연도        2005       2010       2015
# 지역
# 경상권  3512547.0  3393191.0  3448737.0
# 수도권  9762546.0  6131758.5  6397381.5

# %% [markdown]
# #### 4. 복수 집계 함수 지정

# %%
pivot_table(df,
            index="지역",
            columns="연도",
            values="인구",
            aggfunc=["sum","mean"])
# Out:
#          sum                           mean
# 연도      2005      2010      2015       2005       2010       2015
# 지역
# 경상권  3512547   3393191   3448737  3512547.0  3393191.0  3448737.0
# 수도권  9762546  12263517  12794763  9762546.0  6131758.5  6397381.5

# %% [markdown]
# #### 5. 복수 인덱스 지정

# %%
pivot_table(df,
            index=["지역","연도"],
            columns="도시",
            values="인구",
            aggfunc = ["mean","sum"]
            )
# Out:
#                mean                              sum
# 도시               부산         서울         인천         부산         서울         인천
# 지역  연도
# 경상권 2005  3512547.0        NaN        NaN  3512547.0        NaN        NaN
#     2010  3393191.0        NaN        NaN  3393191.0        NaN        NaN
#     2015  3448737.0        NaN        NaN  3448737.0        NaN        NaN
# 수도권 2005        NaN  9762546.0        NaN        NaN  9762546.0        NaN
#     2010        NaN  9631482.0  2632035.0        NaN  9631482.0  2632035.0
#     2015        NaN  9904312.0  2890451.0        NaN  9904312.0  2890451.0

# %% [markdown]
# ## #05 교차표(crosstab)
#
# 범주형 자료를 갖는 데이터에 대해 각 범주별로 빈도수를 계산하여 표현한 표
#
# ### 1. 샘플데이터 가져오기

# %%
df = read_excel("https://data.hossam.kr/C02/city_people.xlsx")
df
# Out:
#    도시    연도       인구   지역
# 0  서울  2015  9904312  수도권
# 1  서울  2010  9631482  수도권
# 2  서울  2005  9762546  수도권
# 3  부산  2015  3448737  경상권
# 4  부산  2010  3393191  경상권
# 5  부산  2005  3512547  경상권
# 6  인천  2015  2890451  수도권
# 7  인천  2010  2632035  수도권

# %% [markdown]
# ### 2. 교차표 만들기
#
# index 파라미터와 columns 파라미터 지정

# %%
crosstab(index=df['gender'],columns=df['score'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 crosstab(index=df['gender'],columns=df['score'])
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'gender'

# %% [markdown]
# ### 3. 파라미터 설정
#
# - rownames : 인덱스 이름 설정
# - colnames : 칼럼이름 설정
# - margins : 집계결과 포함여부 (True / False)

# %%
crosstab(index=df['gender'],columns=df['score'],colnames=['점수'],rownames=['성별'],
margins=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 crosstab(index=df['gender'],columns=df['score'],colnames=['점수'],rownames=['성별'],
#       2 margins=True)
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'gender'

# %% [markdown]
# ### 4. 비율표시
#
# - normalize = True 파라미터 사용

# %%
crosstab(index=df['gender'],columns=df['score'],colnames=['점수'],rownames=['성별'],normalize=True,margins=True)
# Out:
# 점수       A      B      C  All
# 성별
# M    0.125  0.250  0.125  0.5
# W    0.125  0.125  0.250  0.5
# All  0.250  0.375  0.375  1.0

# %% [markdown]
# ## #03. melt 함수
#
# 데이터 테이블의 칼럼이름을 변수화 한 형태
#
# 피벗테이블을 분리한 것으로 보면됌
#
# ### 샘플 피벗테이블

# %%
df = read_excel("https://data.hossam.kr/C02/city_people.xlsx")
pivot_df = pivot_table(df,              # 피벗할 데이터프레임
            index = '연도',   # 행 위치에 들어갈 열
            columns = '지역', # 열 위치에 들어갈 열
            values = '인구',   # 데이터로 사용할 열
            aggfunc='mean'   # 데이터가 두 개 이상일 경우 집계함수 지정
)

pivot_df
# Out:
# 지역          경상권        수도권
# 연도
# 2005  3512547.0  9762546.0
# 2010  3393191.0  6131758.5
# 2015  3448737.0  6397381.5

# %% [markdown]
# ### 2. 피벗 테이블 분리
#
# - id_vars  : 인덱스로 사용할 컬럼이름. 반드시 컬럼만 가능
# - value_vars : 불리할 칼럼이름들

# %%
# 데이터프레임의 인덱스를 일반 컬럼으로 설정
pivot_df2 = pivot_df.reset_index()
pivot_df2
# Out:
# 지역    연도        경상권        수도권
# 0   2005  3512547.0  9762546.0
# 1   2010  3393191.0  6131758.5
# 2   2015  3448737.0  6397381.5

# %%
## 피벗테이블 분리

mdf = melt(pivot_df2,id_vars=['연도'],value_vars=['경상권','수도권'])
mdf
# Out:
#      연도   지역      value
# 0  2005  경상권  3512547.0
# 1  2010  경상권  3393191.0
# 2  2015  경상권  3448737.0
# 3  2005  수도권  9762546.0
# 4  2010  수도권  6131758.5
# 5  2015  수도권  6397381.5

# %%
# 피벗 테이블 분리 및 필드 이름 지정
mdf = melt(pivot_df2, id_vars=['연도'], value_vars=['경상권', '수도권'],
           var_name='구분', value_name='인구수')
mdf
# Out:
#      연도   구분        인구수
# 0  2005  경상권  3512547.0
# 1  2010  경상권  3393191.0
# 2  2015  경상권  3448737.0
# 3  2005  수도권  9762546.0
# 4  2010  수도권  6131758.5
# 5  2015  수도권  6397381.5

# %% [markdown]
# ## #04. stack, unstack
#
# ### 데이터 분리
#
# 모든 변수를 하나의 변수로 쌓아놓는 처리
#
# ### 샘플데이터 가져오기

# %%
df = read_excel("https://data.hossam.kr/C02/body.xlsx", index_col="name")
df
# Out:
#      sex  height  weight
# name
# Lee    M     175    98.0
# Park   F     167    48.0
# Hong   M     180     NaN
# Kim    F     162    55.0
# Nam    M     172    85.0

# %% [markdown]
# ### stack 처리
#
# 리턴 결과를 Series 객체가 된다.

# %%
st = df.stack()
st
# Out:
# name
# Lee   sex          M
#       height     175
#       weight    98.0
# Park  sex          F
#       height     167
#       weight    48.0
# Hong  sex          M
#       height     180
# Kim   sex          F
#       height     162
#       weight    55.0
# Nam   sex          M
#       height     172
#       weight    85.0
# dtype: object

# %% [markdown]
# ### stack 결과를 DataFrame으로 만들기

# %%
df2 = DataFrame(st)
df2
# Out:
#                 0
# name
# Lee  sex        M
#      height   175
#      weight  98.0
# Park sex        F
#      height   167
#      weight  48.0
# Hong sex        M
#      height   180
# Kim  sex        F
#      height   162
#      weight  55.0
# Nam  sex        M
#      height   172
#      weight  85.0

# %% [markdown]
# 빈 값에 대한 처리
#
#
# dropna=False 파라미터를 적용하면 빈값(NaN)을 유지한다. (기본값=True, 빈값 삭제)

# %%
st2 = df.stack(dropna=False)
st2
# Out:
# name
# Lee   sex          M
#       height     175
#       weight    98.0
# Park  sex          F
#       height     167
#       weight    48.0
# Hong  sex          M
#       height     180
#       weight     NaN
# Kim   sex          F
#       height     162
#       weight    55.0
# Nam   sex          M
#       height     172
#       weight    85.0
# dtype: object

# %% [markdown]
# ### stack 결과를 원래대로 되돌림

# %%
st.unstack()
# Out:
#      sex height weight
# name
# Lee    M    175   98.0
# Park   F    167   48.0
# Hong   M    180    NaN
# Kim    F    162   55.0
# Nam    M    172   85.0

# %% [markdown]
# ### unstack을 수행하면서 빈값을 다른 값으로 대체

# %%
st.unstack(fill_value=100)
# Out:
#      sex height weight
# name
# Lee    M    175   98.0
# Park   F    167   48.0
# Hong   M    180    100
# Kim    F    162   55.0
# Nam    M    172   85.0
