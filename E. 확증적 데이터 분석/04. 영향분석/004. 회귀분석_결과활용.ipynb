# %% [markdown]
# # ext_ols 함수 확인하기

# %%
import pandas as pd
import os, sys

sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))
from helper import ext_ols

# %% [markdown]
# ### 데이터 가져오기

# %%
df= pd.read_excel('https://data.hossam.kr/E04/cars.xlsx')
df
# Out:
#     speed  dist
# 0       4     2
# 1       4    10
# 2       7     4
# 3       7    22
# 4       8    16
# 5       9    10
# 6      10    18
# 7      10    26
# 8      10    34
# 9      11    17
# 10     11    28
# 11     12    14
# 12     12    20
# 13     12    24
# 14     12    28
# 15     13    26
# 16     13    34
# 17     13    34
# 18     13    46
# 19     14    26
# 20     14    36
# 21     14    60
# 22     14    80
# 23     15    20
# 24     15    26
# 25     15    54
# 26     16    32
# 27     16    40
# 28     17    32
# 29     17    40
# 30     17    50
# 31     18    42
# 32     18    56
# 33     18    76
# 34     18    84
# 35     19    36
# 36     19    46
# 37     19    68
# 38     20    32
# 39     20    48
# 40     20    52
# 41     20    56
# 42     20    64
# 43     22    66
# 44     23    54
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %%
model,fit,summary,table,result,goodness,varstr = ext_ols(df,x="speed",y="dist")

# %%
model

# %%
fit

# %%
table
# Out:
#                        B   표준오차  β        t   유의확률  VIF
# 종속변수 독립변수
# dist Intercept  -17.5791  6.758  0  -2.601*  0.012  0.0
#      speed        3.9324  0.416  0   9.464*  0.000  1.0

# %%
result
# Out:
# '𝑅(0.651), 𝑅^2(0.644), 𝐹(89.57), 유의확률(1.49e-12), Durbin-Watson(1.676)'

# %%
goodness
# Out:
# 'dist에 대하여 speed로 예측하는 회귀분석을 실시한 결과, 이 회귀모형은 통계적으로 유의하다(F(1,48) = 89.57, p < 0.05).'

# %%
varstr
# Out:
# ['speed의 회귀계수는 3.9324(p<0.05)로, dist에 대하여 유의미한 예측변인인 것으로 나타났다.']
