# %% [markdown]
# # 네이버 웹툰 정보수집
#
# ###  #01.패키지 참조

# %% [markdown]
# 기존의 request방식으로 크롤링하면 네이버 웹툰사이트 같이 Element 정보가 안나오는 경우가 있음
#
# Selenium
# : 셀리늄은 웹브라우저를 제어할수 있는 패키지
# chrome_driver.exe
# : 셀레늄과 크롬브라우저를 연결 chromedriver_autoinstaller 페키지필요
# : 파이선 스스토 크럼드라이버를 내려받도록 하기 위해
#
#     -> 셀리늄은 1) 특정페이지 접속
#                 2) Element 코드 가죠옴
#                 3) 특정 요소에 키보드 입력 보내기
#                 4) 마우스 클릭 보내기
#                 5) 자바스크립크 실행 -> 스크롤 발생시킴
#
#
#     -> webdriverwait : 크롬 제어기
#     -> time : 지정된 시간동안 랙을 거는 기능

# %% [markdown]
# 요일별 웹툰 -> 한 날짜에서 웹툰별 이미지 링크 -> 웹툰정보 + 웹툰 주소로 이동하는 링크 + 제목 + 작가 + 별점

# %%
# 필요한 모듈 참조

## chromedriver_autoinstaller 자동 설치 모듈
import chromedriver_autoinstaller
## 크롬을 제어하기 위한 객체
from selenium import webdriver

## 크롬이 웹페이지 로딩을 완료할 떄 까지 최대 n초간 대기하는 기능
from selenium.webdriver.support.ui import WebDriverWait

from bs4 import BeautifulSoup
from pandas import DataFrame
import time

# %% [markdown]
# #### #02.크롬브라우저 가동

# %%
## 크롬드라이버 설치 

chromedriver_autoinstaller.install()

## 크롬드라이버를 통해 크롬실행
driver = webdriver.Chrome()
## 크룸브라우저가 준비될 때 최대 5초씩 대기 
driver.implicitly_wait(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 ## 크롬드라이버 설치
# ----> 3 chromedriver_autoinstaller.install()
#       5 ## 크롬드라이버를 통해 크롬실행
#       6 driver = webdriver.Chrome()
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromedriver_autoinstaller\__init__.py:21, in install(cwd, path, no_ssl)
#      19 if cwd:
#      20     path = os.getcwd()
# ---> 21 chromedriver_filepath = utils.download_chromedriver(path, no_ssl)
#      22 if not chromedriver_filepath:
#      23     logging.debug('Can not download chromedriver.')
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromedriver_autoinstaller\utils.py:207, in download_chromedriver(path, no_ssl)
#     205     logging.debug('Chrome is not installed.')
#     206     return
# --> 207 chromedriver_version = get_matched_chromedriver_version(chrome_version, no_ssl)
#     208 if not chromedriver_version:
#     209     logging.warning('Can not find chromedriver for currently installed chrome version.')
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromedriver_autoinstaller\utils.py:172, in get_matched_chromedriver_version(version, no_ssl)
#     170     doc = urllib.request.urlopen('http://chromedriver.storage.googleapis.com').read()
#     171 else:
# --> 172     doc = urllib.request.urlopen('https://chromedriver.storage.googleapis.com').read()
#     173 root = elemTree.fromstring(doc)
#     174 for k in root.iter('{http://doc.s3.amazonaws.com/2006-03-01}Key'):
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1352, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350     except OSError as err: # timeout error
#    1351         raise URLError(err)
# -> 1352     r = h.getresponse()
#    1353 except:
#    1354     h.close()
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\hamin\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#  요일별 네이버 웹툰에 접근하기 위한 변수값
# -> url을 분석하여 얻어낸 값 

params = ['mon','tue','wed','thu','fri','sat','sun','dailyPlus']

## 네이버 웹툰의 주소형식 

naverWebtoonUrl = "https://comic.naver.com/webtoon?tab={0}"

# %% [markdown]
# #### #03. 응답결과로부터 내용 추출하기

# %%
## 수집된 결과가 누적될 빈 리스트 

naverWebtoonList = []
## 요일 + 포스터 url + 웹툰 url + 작가이름 + 별점 
for p in params :
    ## 웹페이지를 요일별로 열어야함. 
    url=naverWebtoonUrl.format(p)
    # print(url)
    ## 접속
    # driver.get(url)
    # time.sleep(1)
    ## 브라우저에 표시되는 전체코드를 추출 후
    soup = BeautifulSoup(driver.page_source)
    # print(soup)
    ## 웹툰리스트 셀렉트
    webtoonList = soup.select(".ContentList__content_list--q5KXY > .item")
    print(webtoonList)
    ## 웹툰에서 데이터 뽑아내야하므로 for 문 써야함 
    for w in webtoonList :
        ## 포스터링크
        posterEl = w.select(".Poster__image--d9XTI")
# Out:
# [<li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=727784"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M1.953 2.097c0 2.199-.161 7.11.228 9.054C3.402 17.265 10 19.711 10 19.711s6.598-2.446 7.819-8.56c.389-1.945.227-6.855.227-9.054C18.046 2.097 14.237 1 10 1 5.763 1 1.953 2.097 1.953 2.097Z" fill="#F4831F" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M10 4.402a2.34 2.34 0 0 0-2.34 2.339c0 1.29 1.05 2.339 2.34 2.339a2.34 2.34 0 0 0 0-4.678Zm2.695 5.382c-.036-.02-.07-.04-.11-.059a1.522 1.522 0 0 0-.14-.057 3.783 3.783 0 0 0-.49-.163c-.574.4-1.257.615-1.956.617-.722 0-1.393-.23-1.956-.617-.212.054-.42.126-.62.215-.052.024-.096.05-.14.075a2.552 2.552 0 0 0-1.323 2.257 7.015 7.015 0 0 0 8.08 0 2.55 2.55 0 0 0-1.345-2.268Z" fill="#fff" fill-rule="evenodd"></path></svg><span class="blind">청유물</span></i></div><img alt="[드라마원작] 사냥개들" class="Poster__image--d9XTI" src="https://image-comic.pstatic.net/webtoon/727784/thumbnail/thumbnail_IMAG21_25e4ca79-9ea7-4f52-ac62-473b0bc2f360.jpg"/></div></a><div class="ContentList__info_area--bXx7h"><a class="ContentTitle__title_area--x24vt" href="/webtoon/list?titleId=727784"><span class="ContentTitle__title--e3qXt"><span class="text">[드라마원작] 사냥개들</span></span></a><a class="ContentAuthor__author--CTAAP" href="/artistTitle?id=325574">정찬</a><div class="rating_area"><span class="Rating__star_area--dFzsb"><i class="Rating__ico_star--BcfMb"><svg aria-hidden="true" fill="none" height="19" width="12" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M6.25 12.991a.529.529 0 0 0-.5 0l-2.578 1.384a.529.529 0 0 1-.753-.632l.882-2.682a.529.529 0 0 0-.17-.576L.596 8.438a.529.529 0 0 1 .299-.94l3.049-.191a.529.529 0 0 0 .457-.33L5.51 4.22a.529.529 0 0 1 .982 0l1.107 2.756c.077.19.255.318.458.33l3.049.192c.481.03.674.637.299.94l-2.535 2.047a.529.529 0 0 0-.17.576l.881 2.682a.529.529 0 0 1-.752.632L6.25 12.99Z" fill="#999" fill-rule="evenodd"></path></svg><span class="blind">별점</span></i><span class="text">9.78</span></span></div></div></li>, <li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=807436"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i></div><img alt="원룸" class="Poster__image--d9XTI" src="https://i ...
# [<li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=727784"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M1.953 2.097c0 2.199-.161 7.11.228 9.054C3.402 17.265 10 19.711 10 19.711s6.598-2.446 7.819-8.56c.389-1.945.227-6.855.227-9.054C18.046 2.097 14.237 1 10 1 5.763 1 1.953 2.097 1.953 2.097Z" fill="#F4831F" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M10 4.402a2.34 2.34 0 0 0-2.34 2.339c0 1.29 1.05 2.339 2.34 2.339a2.34 2.34 0 0 0 0-4.678Zm2.695 5.382c-.036-.02-.07-.04-.11-.059a1.522 1.522 0 0 0-.14-.057 3.783 3.783 0 0 0-.49-.163c-.574.4-1.257.615-1.956.617-.722 0-1.393-.23-1.956-.617-.212.054-.42.126-.62.215-.052.024-.096.05-.14.075a2.552 2.552 0 0 0-1.323 2.257 7.015 7.015 0 0 0 8.08 0 2.55 2.55 0 0 0-1.345-2.268Z" fill="#fff" fill-rule="evenodd"></path></svg><span class="blind">청유물</span></i></div><img alt="[드라마원작] 사냥개들" class="Poster__image--d9XTI" src="https://image-comic.pstatic.net/webtoon/727784/thumbnail/thumbnail_IMAG21_25e4ca79-9ea7-4f52-ac62-473b0bc2f360.jpg"/></div></a><div class="ContentList__info_area--bXx7h"><a class="ContentTitle__title_area--x24vt" href="/webtoon/list?titleId=727784"><span class="ContentTitle__title--e3qXt"><span class="text">[드라마원작] 사냥개들</span></span></a><a class="ContentAuthor__author--CTAAP" href="/artistTitle?id=325574">정찬</a><div class="rating_area"><span class="Rating__star_area--dFzsb"><i class="Rating__ico_star--BcfMb"><svg aria-hidden="true" fill="none" height="19" width="12" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M6.25 12.991a.529.529 0 0 0-.5 0l-2.578 1.384a.529.529 0 0 1-.753-.632l.882-2.682a.529.529 0 0 0-.17-.576L.596 8.438a.529.529 0 0 1 .299-.94l3.049-.191a.529.529 0 0 0 .457-.33L5.51 4.22a.529.529 0 0 1 .982 0l1.107 2.756c.077.19.255.318.458.33l3.049.192c.481.03.674.637.299.94l-2.535 2.047a.529.529 0 0 0-.17.576l.881 2.682a.529.529 0 0 1-.752.632L6.25 12.99Z" fill="#999" fill-rule="evenodd"></path></svg><span class="blind">별점</span></i><span class="text">9.78</span></span></div></div></li>, <li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=807436"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i></div><img alt="원룸" class="Poster__image--d9XTI" src="https://i ...
# [<li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=727784"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M1.953 2.097c0 2.199-.161 7.11.228 9.054C3.402 17.265 10 19.711 10 19.711s6.598-2.446 7.819-8.56c.389-1.945.227-6.855.227-9.054C18.046 2.097 14.237 1 10 1 5.763 1 1.953 2.097 1.953 2.097Z" fill="#F4831F" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M10 4.402a2.34 2.34 0 0 0-2.34 2.339c0 1.29 1.05 2.339 2.34 2.339a2.34 2.34 0 0 0 0-4.678Zm2.695 5.382c-.036-.02-.07-.04-.11-.059a1.522 1.522 0 0 0-.14-.057 3.783 3.783 0 0 0-.49-.163c-.574.4-1.257.615-1.956.617-.722 0-1.393-.23-1.956-.617-.212.054-.42.126-.62.215-.052.024-.096.05-.14.075a2.552 2.552 0 0 0-1.323 2.257 7.015 7.015 0 0 0 8.08 0 2.55 2.55 0 0 0-1.345-2.268Z" fill="#fff" fill-rule="evenodd"></path></svg><span class="blind">청유물</span></i></div><img alt="[드라마원작] 사냥개들" class="Poster__image--d9XTI" src="https://image-comic.pstatic.net/webtoon/727784/thumbnail/thumbnail_IMAG21_25e4ca79-9ea7-4f52-ac62-473b0bc2f360.jpg"/></div></a><div class="ContentList__info_area--bXx7h"><a class="ContentTitle__title_area--x24vt" href="/webtoon/list?titleId=727784"><span class="ContentTitle__title--e3qXt"><span class="text">[드라마원작] 사냥개들</span></span></a><a class="ContentAuthor__author--CTAAP" href="/artistTitle?id=325574">정찬</a><div class="rating_area"><span class="Rating__star_area--dFzsb"><i class="Rating__ico_star--BcfMb"><svg aria-hidden="true" fill="none" height="19" width="12" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M6.25 12.991a.529.529 0 0 0-.5 0l-2.578 1.384a.529.529 0 0 1-.753-.632l.882-2.682a.529.529 0 0 0-.17-.576L.596 8.438a.529.529 0 0 1 .299-.94l3.049-.191a.529.529 0 0 0 .457-.33L5.51 4.22a.529.529 0 0 1 .982 0l1.107 2.756c.077.19.255.318.458.33l3.049.192c.481.03.674.637.299.94l-2.535 2.047a.529.529 0 0 0-.17.576l.881 2.682a.529.529 0 0 1-.752.632L6.25 12.99Z" fill="#999" fill-rule="evenodd"></path></svg><span class="blind">별점</span></i><span class="text">9.78</span></span></div></div></li>, <li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=807436"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i></div><img alt="원룸" class="Poster__image--d9XTI" src="https://i ...
# [<li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=727784"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M1.953 2.097c0 2.199-.161 7.11.228 9.054C3.402 17.265 10 19.711 10 19.711s6.598-2.446 7.819-8.56c.389-1.945.227-6.855.227-9.054C18.046 2.097 14.237 1 10 1 5.763 1 1.953 2.097 1.953 2.097Z" fill="#F4831F" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M10 4.402a2.34 2.34 0 0 0-2.34 2.339c0 1.29 1.05 2.339 2.34 2.339a2.34 2.34 0 0 0 0-4.678Zm2.695 5.382c-.036-.02-.07-.04-.11-.059a1.522 1.522 0 0 0-.14-.057 3.783 3.783 0 0 0-.49-.163c-.574.4-1.257.615-1.956.617-.722 0-1.393-.23-1.956-.617-.212.054-.42.126-.62.215-.052.024-.096.05-.14.075a2.552 2.552 0 0 0-1.323 2.257 7.015 7.015 0 0 0 8.08 0 2.55 2.55 0 0 0-1.345-2.268Z" fill="#fff" fill-rule="evenodd"></path></svg><span class="blind">청유물</span></i></div><img alt="[드라마원작] 사냥개들" class="Poster__image--d9XTI" src="https://image-comic.pstatic.net/webtoon/727784/thumbnail/thumbnail_IMAG21_25e4ca79-9ea7-4f52-ac62-473b0bc2f360.jpg"/></div></a><div class="ContentList__info_area--bXx7h"><a class="ContentTitle__title_area--x24vt" href="/webtoon/list?titleId=727784"><span class="ContentTitle__title--e3qXt"><span class="text">[드라마원작] 사냥개들</span></span></a><a class="ContentAuthor__author--CTAAP" href="/artistTitle?id=325574">정찬</a><div class="rating_area"><span class="Rating__star_area--dFzsb"><i class="Rating__ico_star--BcfMb"><svg aria-hidden="true" fill="none" height="19" width="12" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M6.25 12.991a.529.529 0 0 0-.5 0l-2.578 1.384a.529.529 0 0 1-.753-.632l.882-2.682a.529.529 0 0 0-.17-.576L.596 8.438a.529.529 0 0 1 .299-.94l3.049-.191a.529.529 0 0 0 .457-.33L5.51 4.22a.529.529 0 0 1 .982 0l1.107 2.756c.077.19.255.318.458.33l3.049.192c.481.03.674.637.299.94l-2.535 2.047a.529.529 0 0 0-.17.576l.881 2.682a.529.529 0 0 1-.752.632L6.25 12.99Z" fill="#999" fill-rule="evenodd"></path></svg><span class="blind">별점</span></i><span class="text">9.78</span></span></div></div></li>, <li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=807436"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i></div><img alt="원룸" class="Poster__image--d9XTI" src="https://i ...
# [<li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=727784"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M1.953 2.097c0 2.199-.161 7.11.228 9.054C3.402 17.265 10 19.711 10 19.711s6.598-2.446 7.819-8.56c.389-1.945.227-6.855.227-9.054C18.046 2.097 14.237 1 10 1 5.763 1 1.953 2.097 1.953 2.097Z" fill="#F4831F" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M10 4.402a2.34 2.34 0 0 0-2.34 2.339c0 1.29 1.05 2.339 2.34 2.339a2.34 2.34 0 0 0 0-4.678Zm2.695 5.382c-.036-.02-.07-.04-.11-.059a1.522 1.522 0 0 0-.14-.057 3.783 3.783 0 0 0-.49-.163c-.574.4-1.257.615-1.956.617-.722 0-1.393-.23-1.956-.617-.212.054-.42.126-.62.215-.052.024-.096.05-.14.075a2.552 2.552 0 0 0-1.323 2.257 7.015 7.015 0 0 0 8.08 0 2.55 2.55 0 0 0-1.345-2.268Z" fill="#fff" fill-rule="evenodd"></path></svg><span class="blind">청유물</span></i></div><img alt="[드라마원작] 사냥개들" class="Poster__image--d9XTI" src="https://image-comic.pstatic.net/webtoon/727784/thumbnail/thumbnail_IMAG21_25e4ca79-9ea7-4f52-ac62-473b0bc2f360.jpg"/></div></a><div class="ContentList__info_area--bXx7h"><a class="ContentTitle__title_area--x24vt" href="/webtoon/list?titleId=727784"><span class="ContentTitle__title--e3qXt"><span class="text">[드라마원작] 사냥개들</span></span></a><a class="ContentAuthor__author--CTAAP" href="/artistTitle?id=325574">정찬</a><div class="rating_area"><span class="Rating__star_area--dFzsb"><i class="Rating__ico_star--BcfMb"><svg aria-hidden="true" fill="none" height="19" width="12" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M6.25 12.991a.529.529 0 0 0-.5 0l-2.578 1.384a.529.529 0 0 1-.753-.632l.882-2.682a.529.529 0 0 0-.17-.576L.596 8.438a.529.529 0 0 1 .299-.94l3.049-.191a.529.529 0 0 0 .457-.33L5.51 4.22a.529.529 0 0 1 .982 0l1.107 2.756c.077.19.255.318.458.33l3.049.192c.481.03.674.637.299.94l-2.535 2.047a.529.529 0 0 0-.17.576l.881 2.682a.529.529 0 0 1-.752.632L6.25 12.99Z" fill="#999" fill-rule="evenodd"></path></svg><span class="blind">별점</span></i><span class="text">9.78</span></span></div></div></li>, <li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=807436"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i></div><img alt="원룸" class="Poster__image--d9XTI" src="https://i ...
# [<li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=727784"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M1.953 2.097c0 2.199-.161 7.11.228 9.054C3.402 17.265 10 19.711 10 19.711s6.598-2.446 7.819-8.56c.389-1.945.227-6.855.227-9.054C18.046 2.097 14.237 1 10 1 5.763 1 1.953 2.097 1.953 2.097Z" fill="#F4831F" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M10 4.402a2.34 2.34 0 0 0-2.34 2.339c0 1.29 1.05 2.339 2.34 2.339a2.34 2.34 0 0 0 0-4.678Zm2.695 5.382c-.036-.02-.07-.04-.11-.059a1.522 1.522 0 0 0-.14-.057 3.783 3.783 0 0 0-.49-.163c-.574.4-1.257.615-1.956.617-.722 0-1.393-.23-1.956-.617-.212.054-.42.126-.62.215-.052.024-.096.05-.14.075a2.552 2.552 0 0 0-1.323 2.257 7.015 7.015 0 0 0 8.08 0 2.55 2.55 0 0 0-1.345-2.268Z" fill="#fff" fill-rule="evenodd"></path></svg><span class="blind">청유물</span></i></div><img alt="[드라마원작] 사냥개들" class="Poster__image--d9XTI" src="https://image-comic.pstatic.net/webtoon/727784/thumbnail/thumbnail_IMAG21_25e4ca79-9ea7-4f52-ac62-473b0bc2f360.jpg"/></div></a><div class="ContentList__info_area--bXx7h"><a class="ContentTitle__title_area--x24vt" href="/webtoon/list?titleId=727784"><span class="ContentTitle__title--e3qXt"><span class="text">[드라마원작] 사냥개들</span></span></a><a class="ContentAuthor__author--CTAAP" href="/artistTitle?id=325574">정찬</a><div class="rating_area"><span class="Rating__star_area--dFzsb"><i class="Rating__ico_star--BcfMb"><svg aria-hidden="true" fill="none" height="19" width="12" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M6.25 12.991a.529.529 0 0 0-.5 0l-2.578 1.384a.529.529 0 0 1-.753-.632l.882-2.682a.529.529 0 0 0-.17-.576L.596 8.438a.529.529 0 0 1 .299-.94l3.049-.191a.529.529 0 0 0 .457-.33L5.51 4.22a.529.529 0 0 1 .982 0l1.107 2.756c.077.19.255.318.458.33l3.049.192c.481.03.674.637.299.94l-2.535 2.047a.529.529 0 0 0-.17.576l.881 2.682a.529.529 0 0 1-.752.632L6.25 12.99Z" fill="#999" fill-rule="evenodd"></path></svg><span class="blind">별점</span></i><span class="text">9.78</span></span></div></div></li>, <li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=807436"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i></div><img alt="원룸" class="Poster__image--d9XTI" src="https://i ...
# [<li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=727784"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M1.953 2.097c0 2.199-.161 7.11.228 9.054C3.402 17.265 10 19.711 10 19.711s6.598-2.446 7.819-8.56c.389-1.945.227-6.855.227-9.054C18.046 2.097 14.237 1 10 1 5.763 1 1.953 2.097 1.953 2.097Z" fill="#F4831F" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M10 4.402a2.34 2.34 0 0 0-2.34 2.339c0 1.29 1.05 2.339 2.34 2.339a2.34 2.34 0 0 0 0-4.678Zm2.695 5.382c-.036-.02-.07-.04-.11-.059a1.522 1.522 0 0 0-.14-.057 3.783 3.783 0 0 0-.49-.163c-.574.4-1.257.615-1.956.617-.722 0-1.393-.23-1.956-.617-.212.054-.42.126-.62.215-.052.024-.096.05-.14.075a2.552 2.552 0 0 0-1.323 2.257 7.015 7.015 0 0 0 8.08 0 2.55 2.55 0 0 0-1.345-2.268Z" fill="#fff" fill-rule="evenodd"></path></svg><span class="blind">청유물</span></i></div><img alt="[드라마원작] 사냥개들" class="Poster__image--d9XTI" src="https://image-comic.pstatic.net/webtoon/727784/thumbnail/thumbnail_IMAG21_25e4ca79-9ea7-4f52-ac62-473b0bc2f360.jpg"/></div></a><div class="ContentList__info_area--bXx7h"><a class="ContentTitle__title_area--x24vt" href="/webtoon/list?titleId=727784"><span class="ContentTitle__title--e3qXt"><span class="text">[드라마원작] 사냥개들</span></span></a><a class="ContentAuthor__author--CTAAP" href="/artistTitle?id=325574">정찬</a><div class="rating_area"><span class="Rating__star_area--dFzsb"><i class="Rating__ico_star--BcfMb"><svg aria-hidden="true" fill="none" height="19" width="12" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M6.25 12.991a.529.529 0 0 0-.5 0l-2.578 1.384a.529.529 0 0 1-.753-.632l.882-2.682a.529.529 0 0 0-.17-.576L.596 8.438a.529.529 0 0 1 .299-.94l3.049-.191a.529.529 0 0 0 .457-.33L5.51 4.22a.529.529 0 0 1 .982 0l1.107 2.756c.077.19.255.318.458.33l3.049.192c.481.03.674.637.299.94l-2.535 2.047a.529.529 0 0 0-.17.576l.881 2.682a.529.529 0 0 1-.752.632L6.25 12.99Z" fill="#999" fill-rule="evenodd"></path></svg><span class="blind">별점</span></i><span class="text">9.78</span></span></div></div></li>, <li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=807436"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i></div><img alt="원룸" class="Poster__image--d9XTI" src="https://i ...
# [<li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=727784"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M1.953 2.097c0 2.199-.161 7.11.228 9.054C3.402 17.265 10 19.711 10 19.711s6.598-2.446 7.819-8.56c.389-1.945.227-6.855.227-9.054C18.046 2.097 14.237 1 10 1 5.763 1 1.953 2.097 1.953 2.097Z" fill="#F4831F" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M10 4.402a2.34 2.34 0 0 0-2.34 2.339c0 1.29 1.05 2.339 2.34 2.339a2.34 2.34 0 0 0 0-4.678Zm2.695 5.382c-.036-.02-.07-.04-.11-.059a1.522 1.522 0 0 0-.14-.057 3.783 3.783 0 0 0-.49-.163c-.574.4-1.257.615-1.956.617-.722 0-1.393-.23-1.956-.617-.212.054-.42.126-.62.215-.052.024-.096.05-.14.075a2.552 2.552 0 0 0-1.323 2.257 7.015 7.015 0 0 0 8.08 0 2.55 2.55 0 0 0-1.345-2.268Z" fill="#fff" fill-rule="evenodd"></path></svg><span class="blind">청유물</span></i></div><img alt="[드라마원작] 사냥개들" class="Poster__image--d9XTI" src="https://image-comic.pstatic.net/webtoon/727784/thumbnail/thumbnail_IMAG21_25e4ca79-9ea7-4f52-ac62-473b0bc2f360.jpg"/></div></a><div class="ContentList__info_area--bXx7h"><a class="ContentTitle__title_area--x24vt" href="/webtoon/list?titleId=727784"><span class="ContentTitle__title--e3qXt"><span class="text">[드라마원작] 사냥개들</span></span></a><a class="ContentAuthor__author--CTAAP" href="/artistTitle?id=325574">정찬</a><div class="rating_area"><span class="Rating__star_area--dFzsb"><i class="Rating__ico_star--BcfMb"><svg aria-hidden="true" fill="none" height="19" width="12" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M6.25 12.991a.529.529 0 0 0-.5 0l-2.578 1.384a.529.529 0 0 1-.753-.632l.882-2.682a.529.529 0 0 0-.17-.576L.596 8.438a.529.529 0 0 1 .299-.94l3.049-.191a.529.529 0 0 0 .457-.33L5.51 4.22a.529.529 0 0 1 .982 0l1.107 2.756c.077.19.255.318.458.33l3.049.192c.481.03.674.637.299.94l-2.535 2.047a.529.529 0 0 0-.17.576l.881 2.682a.529.529 0 0 1-.752.632L6.25 12.99Z" fill="#999" fill-rule="evenodd"></path></svg><span class="blind">별점</span></i><span class="text">9.78</span></span></div></div></li>, <li class="item"><a class="Poster__link--sopnC" href="/webtoon/list?titleId=807436"><div class="Poster__thumbnail_area--gviWY Poster__type160x207--EQAM8"><div class="Poster__bullet_wrap--VcWFJ"><i class="Poster__icon_bullet--D4lUU"><svg aria-hidden="true" fill="none" height="20" width="20" xmlns="http://www.w3.org/2000/svg"><circle cx="10" cy="10" fill="#000" opacity="0.7" r="10"></circle><path d="M2.292 10a7.708 7.708 0 1 0 7.717-7.708" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path><path clip-rule="evenodd" d="M5.182 4.665a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM7.582 2.974a.708.708 0 1 1-1.417 0 .708.708 0 0 1 1.417 0ZM2.87 7.833a.708.708 0 1 1 0-1.416.708.708 0 0 1 0 1.416Z" fill="#00DC64" fill-rule="evenodd"></path><path d="M10 5v5" stroke="#00DC64" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.276"></path></svg><span class="blind">유료작품</span></i></div><img alt="원룸" class="Poster__image--d9XTI" src="https://i ...
